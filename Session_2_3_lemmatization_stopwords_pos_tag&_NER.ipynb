# %%
## Tokenization
## libarary required ----> nltk
# !pip install nltk

# %%
from nltk.tokenize import TreebankWordTokenizer, sent_tokenize
token = TreebankWordTokenizer()

# %%
corpus = """
Hello world! This is a test corpus for tokenizer evaluation.
Tokenizers split text into smaller units called tokens.

Numbers: 123, 45.67, and dates like 2026-06-04.
Special characters: @username, #hashtag, email@example.com.
"""

# %%
lst_token = token.tokenize(corpus)
lst = set(lst_token)
print("Unique tokens: ", lst)
# Out:
# Unique tokens:  {'called', 'a', '.', ':', 'like', '@', 'split', 'Numbers', 'world', 'Tokenizers', '!', 'characters', '#', 'hashtag', 'corpus', 'evaluation.', 'and', 'tokens.', 'example.com', 'Special', 'smaller', 'email', 'units', 'for', '123', 'dates', 'test', ',', '2026-06-04.', 'tokenizer', 'into', 'Hello', 'text', 'is', 'This', '45.67', 'username'}

# %%
# nltk.download('punkt_tab')
content = sent_tokenize(corpus)
for sent in content:
    print(sent)
# Out:
# Hello world!
# This is a test corpus for tokenizer evaluation.
# Tokenizers split text into smaller units called tokens.
# Numbers: 123, 45.67, and dates like 2026-06-04.
# Special characters: @username, #hashtag, email@example.com.

# %%
## Text preprocessing ---> stemming
from nltk.stem import PorterStemmer
port = PorterStemmer()

# %%
print(lst_token)
# Out:
# ['Hello', 'world', '!', 'This', 'is', 'a', 'test', 'corpus', 'for', 'tokenizer', 'evaluation.', 'Tokenizers', 'split', 'text', 'into', 'smaller', 'units', 'called', 'tokens.', 'Numbers', ':', '123', ',', '45.67', ',', 'and', 'dates', 'like', '2026-06-04.', 'Special', 'characters', ':', '@', 'username', ',', '#', 'hashtag', ',', 'email', '@', 'example.com', '.']

# %%
for i in lst_token:
    new = port.stem(i)
    print(f" {i} -----> {new}")
# Out:
#  Hello -----> hello
#  world -----> world
#  ! -----> !
#  This -----> thi
#  is -----> is
#  a -----> a
#  test -----> test
#  corpus -----> corpu
#  for -----> for
#  tokenizer -----> token
#  evaluation. -----> evaluation.
#  Tokenizers -----> token
#  split -----> split
#  text -----> text
#  into -----> into
#  smaller -----> smaller
#  units -----> unit
#  called -----> call
#  tokens. -----> tokens.
#  Numbers -----> number
#  : -----> :
#  123 -----> 123
#  , -----> ,
#  45.67 -----> 45.67
#  , -----> ,
#  and -----> and
#  dates -----> date
#  like -----> like
#  2026-06-04. -----> 2026-06-04.
#  Special -----> special
#  characters -----> charact
#  : -----> :
#  @ -----> @
#  username -----> usernam
#  , -----> ,
#  # -----> #
#  hashtag -----> hashtag
#  , -----> ,
#  email -----> email
#  @ -----> @
#  example.com -----> example.com
#  . -----> .

# %%
## regexstemmer ---> based on patterns present within word it gives us root words
from nltk.stem import RegexpStemmer
rgx = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
rgx.stem("drinking")
# Out:
# 'drink'

# %%
rgx.stem("caring")
# Out:
# 'car'

# %%
rgx.stem("Winning")
# Out:
# 'Winn'

# %%
## snowball stemmer
from nltk.stem import SnowballStemmer
snow = SnowballStemmer("english")

# %%
snow.stem("caring")
# Out:
# 'care'

# %%
snow.stem("congratulations")
# Out:
# 'congratul'

# %%
snow.stem("winning")
# Out:
# 'win'

# %% [raw]
# ## Lemmatization ->>> lemma --- root word ---> works on actual meaning and root word of the
# given token ----> WordNetLemmatizer

# %%
import nltk
from nltk import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\NachiketDixit\AppData\Roaming\nltk_data...
# True

# %%
lemma = WordNetLemmatizer()

# %%
lemma.lemmatize("going", pos = "v")
# Out:
# 'go'

# %%
corpus_1 = """Small enough to fit in the palm of a hand, NASA’s High Performance Spaceflight 
Computing processor packs the power of a full system-on-a-chip. This next-generation processor 
is made to survive deep space while delivering a massive leap 
in computational speed compared to current spacecraft technology. 
NASA is developing a powerful new computer chip designed to dramatically increase the intelligence and performance of future 
spacecraft. Through a commercial partnership, the project is creating advanced processing technology capable of helping spacecraft
operate more independently during missions far from Earth.
NASA's High Performance Spaceflight Computing project is focused on boosting the computing capabilities of 
spacecraft used in space exploration. Current missions rely on older processors because they are durable enough to survive 
the extreme conditions of space. While those chips are dependable, they lack the performance needed for more advanced missions."""

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
sentences = word_tokenize(corpus_1)
for word in sentences:
    
    wrd_new = lemma.lemmatize(word, pos="v")
    print(f"{word} ----> {wrd_new}")
# Out:
# Small ----> Small
# enough ----> enough
# to ----> to
# fit ----> fit
# in ----> in
# the ----> the
# palm ----> palm
# of ----> of
# a ----> a
# hand ----> hand
# , ----> ,
# NASA ----> NASA
# ’ ----> ’
# s ----> s
# High ----> High
# Performance ----> Performance
# Spaceflight ----> Spaceflight
# Computing ----> Computing
# processor ----> processor
# packs ----> pack
# the ----> the
# power ----> power
# of ----> of
# a ----> a
# full ----> full
# system-on-a-chip ----> system-on-a-chip
# . ----> .
# This ----> This
# next-generation ----> next-generation
# processor ----> processor
# is ----> be
# made ----> make
# to ----> to
# survive ----> survive
# deep ----> deep
# space ----> space
# while ----> while
# delivering ----> deliver
# a ----> a
# massive ----> massive
# leap ----> leap
# in ----> in
# computational ----> computational
# speed ----> speed
# compared ----> compare
# to ----> to
# current ----> current
# spacecraft ----> spacecraft
# technology ----> technology
# ...

# %%
from nltk.corpus import stopwords
# nltk.download('stopwords')
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
sentences = word_tokenize(corpus_1)
cleaned_wrd_lst = []
for word in sentences:
    if word not in stopwords.words("english") and word not in "’.,''s":
        wrd_new = lemma.lemmatize(word, pos="v")
        print(f"{word} ----> {wrd_new}")
        cleaned_wrd_lst.append(wrd_new)
# Out:
# Small ----> Small
# enough ----> enough
# fit ----> fit
# palm ----> palm
# hand ----> hand
# NASA ----> NASA
# High ----> High
# Performance ----> Performance
# Spaceflight ----> Spaceflight
# Computing ----> Computing
# processor ----> processor
# packs ----> pack
# power ----> power
# full ----> full
# system-on-a-chip ----> system-on-a-chip
# This ----> This
# next-generation ----> next-generation
# processor ----> processor
# made ----> make
# survive ----> survive
# deep ----> deep
# space ----> space
# delivering ----> deliver
# massive ----> massive
# leap ----> leap
# computational ----> computational
# speed ----> speed
# compared ----> compare
# current ----> current
# spacecraft ----> spacecraft
# technology ----> technology
# NASA ----> NASA
# developing ----> develop
# powerful ----> powerful
# new ----> new
# computer ----> computer
# chip ----> chip
# designed ----> design
# dramatically ----> dramatically
# increase ----> increase
# intelligence ----> intelligence
# ...

# %%
cleaned_wrd_lst
# Out:
# ['Small',
#  'enough',
#  'fit',
#  'palm',
#  'hand',
#  'NASA',
#  'High',
#  'Performance',
#  'Spaceflight',
#  'Computing',
#  'processor',
#  'pack',
#  'power',
#  'full',
#  'system-on-a-chip',
#  'This',
#  'next-generation',
#  'processor',
#  'make',
#  'survive',
#  'deep',
#  'space',
#  'deliver',
#  'massive',
#  'leap',
#  'computational',
#  'speed',
#  'compare',
#  'current',
#  'spacecraft',
#  'technology',
#  'NASA',
#  'develop',
#  'powerful',
#  'new',
#  'computer',
#  'chip',
#  'design',
#  'dramatically',
#  'increase',
#  'intelligence',
#  'performance',
#  'future',
#  'spacecraft',
#  'Through',
#  'commercial',
#  'partnership',
#  'project',
#  'create',
#  'advance',
#  'process',
#  'technology',
#  'capable',
#  'help',
#  'spacecraft',
#  'operate',
#  'independently',
#  'missions',
#  'far',
#  'Earth',
#  'NASA',
#  'High',
#  'Performance',
#  'Spaceflight',
#  'Computing',
#  'project',
#  'focus',
#  'boost',
#  'compute',
# ...

# %%
## POS tagging ---> Part of Speech Tagging ---> ne_chuncks
import nltk
# nltk.download('averaged_perceptron_tagger_eng')

pos_tagged_wrd = nltk.pos_tag(cleaned_wrd_lst)
print(pos_tagged_wrd)
# Out:
# [('Small', 'JJ'), ('enough', 'RB'), ('fit', 'JJ'), ('palm', 'NN'), ('hand', 'NN'), ('NASA', 'NNP'), ('High', 'NNP'), ('Performance', 'NNP'), ('Spaceflight', 'NNP'), ('Computing', 'NNP'), ('processor', 'NN'), ('pack', 'NN'), ('power', 'NN'), ('full', 'JJ'), ('system-on-a-chip', 'NN'), ('This', 'DT'), ('next-generation', 'NN'), ('processor', 'NN'), ('make', 'VBP'), ('survive', 'JJ'), ('deep', 'JJ'), ('space', 'NN'), ('deliver', 'RB'), ('massive', 'JJ'), ('leap', 'NN'), ('computational', 'JJ'), ('speed', 'NN'), ('compare', 'VBP'), ('current', 'JJ'), ('spacecraft', 'NN'), ('technology', 'NN'), ('NASA', 'NNP'), ('develop', 'VB'), ('powerful', 'JJ'), ('new', 'JJ'), ('computer', 'NN'), ('chip', 'NN'), ('design', 'NN'), ('dramatically', 'RB'), ('increase', 'JJ'), ('intelligence', 'NN'), ('performance', 'NN'), ('future', 'NN'), ('spacecraft', 'NN'), ('Through', 'IN'), ('commercial', 'JJ'), ('partnership', 'NN'), ('project', 'NN'), ('create', 'NN'), ('advance', 'NN'), ('process', 'NN'), ('tech
# ...

# %%
## Named Entity Recogition --> It recogizes a person, location, date, time so that it is for ML, DL models 
## to understand actual value of the word
# nltk.download('maxent_ne_chunker_tab')
# nltk.download('words')
# !pip install svgling
chunk = nltk.ne_chunk(pos_tagged_wrd)

# %%
chunk.draw() ## drawing
